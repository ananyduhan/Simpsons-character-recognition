# %% [markdown]
# #starting open cv

# %%
import cv2 as cv

# %%
# reading images
img = cv.imread('pictures/berry cake.jpg')
cv.imshow('berry cake.jpg',img)

cv.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 5
#       1 # reading images
#       2 img = cv.imread('pictures/berry cake.jpg')
#       3 cv.imshow('berry cake.jpg',img)
#       4
# ----> 5 cv.waitKey(0)
#
# KeyboardInterrupt:
